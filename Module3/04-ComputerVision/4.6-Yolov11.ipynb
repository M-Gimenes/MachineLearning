# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n-seg.pt")  # load an official model

# Predict with the model
results = model("../0-Data/golden-gate-modified.jpeg")
results
# Out:
# image 1/1 c:\Users\Matheus\Desktop\Matheus\Programming\Python\MachineLearning\Module3\04-ComputerVision\..\0-Data\golden-gate-modified.jpeg: 448x640 (no detections), 183.0ms
# Speed: 5.0ms preprocess, 183.0ms inference, 6.0ms postprocess per image at shape (1, 3, 448, 640)
# [ultralytics.engine.results.Results object with attributes:
#
#  boxes: ultralytics.engine.results.Boxes object
#  keypoints: None
#  masks: None
#  names: {0: 'person', 1: 'bicycle', 2: 'car', 3: 'motorcycle', 4: 'airplane', 5: 'bus', 6: 'train', 7: 'truck', 8: 'boat', 9: 'traffic light', 10: 'fire hydrant', 11: 'stop sign', 12: 'parking meter', 13: 'bench', 14: 'bird', 15: 'cat', 16: 'dog', 17: 'horse', 18: 'sheep', 19: 'cow', 20: 'elephant', 21: 'bear', 22: 'zebra', 23: 'giraffe', 24: 'backpack', 25: 'umbrella', 26: 'handbag', 27: 'tie', 28: 'suitcase', 29: 'frisbee', 30: 'skis', 31: 'snowboard', 32: 'sports ball', 33: 'kite', 34: 'baseball bat', 35: 'baseball glove', 36: 'skateboard', 37: 'surfboard', 38: 'tennis racket', 39: 'bottle', 40: 'wine glass', 41: 'cup', 42: 'fork', 43: 'knife', 44: 'spoon', 45: 'bowl', 46: 'banana', 47: 'apple', 48: 'sandwich', 49: 'orange', 50: 'broccoli', 51: 'carrot', 52: 'hot dog', 53: 'pizza', 54: 'donut', 55: 'cake', 56: 'chair', 57: 'couch', 58: 'potted plant', 59: 'bed', 60: 'dining table', 61: 'toilet', 62: 'tv', 63: 'laptop', 64: 'mouse', 65: 'remote', 66: 'keyboard', 67: 'cell phone', 68: 'microwave', 69: 'oven', 70: 'toaster', 71: 'sink', 72: 'refrigerator', 73: 'book', 74: 'clock', 75: 'vase', 76: 'scissors', 77: 'teddy bear', 78: 'hair drier', 79: 'toothbrush'}
#  obb: None
#  orig_img: array([[[177, 134,  67],
#          [179, 136,  69],
#          [181, 138,  71],
#          ...,
#          [220, 212, 195],
#          [220, 212, 195],
#          [221, 213, 196]],
#
#         [[178, 134,  70],
#          [180, 137,  70],
#          [182, 139,  72],
#          ...,
#          [220, 212, 195],
#          [220, 212, 195],
#          [221, 213, 196]],
#
#         [[176, 133,  70],
#          [177, 135,  70],
#          [179, 137,  72],
#          ...,
#          [221, 213, 196],
#          [221, 213, 196],
#          [222, 214, 197]],
#
#         ...,
#
#         [[ 54,  66,  72],
#          [ 60,  71,  79],
#          [ 69,  78,  88],
#          ...,
#          [109, 105,  47],
#          [127, 121,  62],
#          [123, 118,  57]],
#
#         [[ 86,  98, 108],
#          [ 76,  86,  96],
#          [ 66,  72,  85],
#          ...,
#          [114, 112,  54],
#          [145, 141,  82],
#          [132, 129,  68]],
#
#         [[119, 131, 143],
#          [ 66,  75,  88],
#          [ 57,  63,  76],
#          ...,
#          [107, 106,  48],
#          [102, 101,  41],
#          [114, 113,  52]]], dtype=uint8)
#  orig_shape: (720, 1080)
#  path: 'c:\\Users\\Matheus\\Desktop\\Matheus\\Programming\\Python\\MachineLearning\\Module3\\04-ComputerVision\\..\\0-Data\\golden-gate-modified.jpeg'
#  probs: None
#  save_dir: 'c:\\Users\\Matheus\\Desktop\\Matheus\\Programming\\Python\\MachineLearning\\runs\\segment\\predict'
#  speed: {'preprocess': 5.003452301025391, 'inference': 182.9996109008789, 'postprocess': 5.995988845825195}]

# %%
import matplotlib.pyplot as plt

annotated_image = results[0].plot()  # Get the annotated image
plt.imshow(annotated_image)
plt.axis('off')
plt.show()
